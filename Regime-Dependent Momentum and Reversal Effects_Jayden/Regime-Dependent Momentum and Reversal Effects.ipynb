# %% [markdown]
# ## **Hypothesis: Regime-Dependent Momentum and Reversal Effects**

# %% [markdown]
# ### **Step 1. Economic Rationale**

# %% [markdown]
# ### **1) Academic Evidence**

# %% [markdown]
# ### **Paper**
#
# - **Title**: *Market-State Dependent Momentum Strategies: An Empirical Examination of Anomalies in Asset Pricing*
# - **Author**: Arnau Rodon Comas (Universitat Pompeu Fabra, University of Essex)
# - **Data**: CRSP stock data (1940–2023, covering NYSE/AMEX/NASDAQ)
# - **Objective**
#   - To test a conditional investment strategy that switches between momentum and reversal depending on market state (bullish/bearish).
#   - To address the limitations of traditional momentum strategies and explore inefficiencies in asset pricing.

# %% [markdown]
# ### **Key Summary**
#
# The **Market-State Dependent Momentum-Reversal Strategy** is a dynamic investment approach that switches between momentum and reversal depending on the **market state**.
#
# - **Bull Market** (positive cumulative return over the past 24 months):
#   → Applies a **momentum strategy** (buying winners, selling losers).
#
# - **Bear Market** (negative cumulative return over the past 24 months):
#   → Applies a **reversal strategy** (buying losers, selling winners).
#
# - **Findings**
#   - Traditional momentum strategies weakened significantly after 2000.
#   - This conditional strategy has **consistently delivered excess returns**.
#   - Achieves an **average monthly excess return of ~1.03% (over 12% annually)** with a **t-statistic of 4.82**, confirming strong statistical significance.

# %% [markdown]
# ### **2) Hypothesis Development**

# %% [markdown]
# **Hypothesis** : Asset pricing anomalies exhibit regime dependency—momentum effects tend to dominate during bull markets, while reversal effects are more pronounced in bear markets. A dynamic investment strategy that conditionally switches between momentum and reversal signals based on market state can deliver superior risk-adjusted returns.

# %% [markdown]
# ### **Step 2. Data Collection**

# %%
# !pip install finance-datareader
# Out:
# Collecting finance-datareader
#   Downloading finance_datareader-0.9.96-py3-none-any.whl (48 kB)
#      ---------------------------------------- 0.0/48.2 kB ? eta -:--:--
#      -------------------------------- ----- 41.0/48.2 kB 991.0 kB/s eta 0:00:01
#      -------------------------------------- 48.2/48.2 kB 808.0 kB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4 in c:\users\shinw\appdata\local\programs\python\python310\lib\site-packages (from finance-datareader) (4.13.3)
# Requirement already satisfied: pandas>=1.1.0 in c:\users\shinw\appdata\local\programs\python\python310\lib\site-packages (from finance-datareader) (2.2.3)
# Requirement already satisfied: requests>=2.3.0 in c:\users\shinw\appdata\local\programs\python\python310\lib\site-packages (from finance-datareader) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\shinw\appdata\local\programs\python\python310\lib\site-packages (from finance-datareader) (4.67.1)
# Requirement already satisfied: plotly in c:\users\shinw\appdata\local\programs\python\python310\lib\site-packages (from finance-datareader) (5.24.1)
# Collecting requests-file
#   Downloading requests_file-2.1.0-py2.py3-none-any.whl (4.2 kB)
# Requirement already satisfied: lxml in c:\users\shinw\appdata\local\programs\python\python310\lib\site-packages (from finance-datareader) (5.3.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\shinw\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.1.0->finance-datareader) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\shinw\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.1.0->finance-datareader) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shinw\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.1.0->finance-datareader) (2025.2)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\shinw\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.1.0->finance-datareader) (1.26.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shinw\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.3.0->finance-datareader) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shinw\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.3.0->finance-datareader) (2025.7.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\shinw\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.3.0->finance-datareader) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shinw\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.3.0->finance-datareader) (3.10)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\shinw\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4->finance-datareader) (4.14.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\shinw\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4->finance-datareader) (2.6)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\shinw\appdata\local\programs\python\python310\lib\site-packages (from plotly->finance-datareader) (9.1.2)
# Requirement already satisfied: packaging in c:\users\shinw\appdata\local\programs\python\python310\lib\site-packages (from plotly->finance-datareader) (24.2)
# Requirement already satisfied: colorama in c:\users\shinw\appdata\local\programs\python\python310\lib\site-packages (from tqdm->finance-datareader) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\shinw\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.1.0->finance-datareader) (1.17.0)
# Installing collected packages: requests-file, finance-datareader
# Successfully installed finance-datareader-0.9.96 requests-file-2.1.0
# [notice] A new release of pip is available: 23.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import FinanceDataReader as fdr
df_all = fdr.StockListing('KOSPI')
print(df_all.columns)
# Out:
# Index(['Code', 'ISU_CD', 'Name', 'Market', 'Dept', 'Close', 'ChangeCode',
#        'Changes', 'ChagesRatio', 'Open', 'High', 'Low', 'Volume', 'Amount',
#        'Marcap', 'Stocks', 'MarketId'],
#       dtype='object')

# %% [markdown]
# 'Code' → 종목코드
# 'Name' → 회사명
# 'Marcap' → 시가총액

# %%
import FinanceDataReader as fdr
import pandas as pd
from tqdm import tqdm

df_all = fdr.StockListing('KOSPI')
kospi200_like = df_all.sort_values(by='Marcap', ascending=False).head(200)
kospi200_like = kospi200_like[['Code', 'Name']]
kospi200_like.columns = ['ticker', 'name']

# 기간 설정
start_date = '2015-01-01'
end_date = '2024-12-31'

price_list = []

for _, row in tqdm(kospi200_like.iterrows(), total=len(kospi200_like)):
    code = row['ticker']
    try:
        df = fdr.DataReader(code, start=start_date, end=end_date)
        df = df[['Close']].copy()
        df.index.name = 'date'
        df['ticker'] = code
        df = df.reset_index()
        
        # 월말 종가 추출
        df['date'] = pd.to_datetime(df['date'])
        df = df.set_index('date').resample('M').last().dropna().reset_index()
        price_list.append(df)

    except Exception as e:
        print(f"[{code}] 에러: {e}")
        continue

df_price = pd.concat(price_list)
df_price = df_price[['date', 'ticker', 'Close']]
df_price.columns = ['date', 'ticker', 'close']

df_price.to_csv("kospi200_fdr_prices_monthly.csv", index=False)
df_price.head()
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#   0%|          | 1/200 [00:00<00:47,  4.17it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#   1%|          | 2/200 [00:00<00:37,  5.34it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#   2%|▏         | 3/200 [00:00<00:31,  6.23it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#   2%|▏         | 4/200 [00:00<00:31,  6.18it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#   2%|▎         | 5/200 [00:00<00:29,  6.60it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#   3%|▎         | 6/200 [00:02<01:38,  1.96it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#   4%|▎         | 7/200 [00:16<16:06,  5.01s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
# C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#   4%|▍         | 9/200 [00:17<08:58,  2.82s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#   5%|▌         | 10/200 [00:17<06:54,  2.18s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#   6%|▌         | 11/200 [00:17<05:11,  1.65s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#   6%|▌         | 12/200 [00:17<03:51,  1.23s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#   6%|▋         | 13/200 [00:18<03:04,  1.01it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#   7%|▋         | 14/200 [00:18<02:21,  1.31it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#   8%|▊         | 15/200 [00:19<02:11,  1.40it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#   8%|▊         | 16/200 [00:19<01:51,  1.65it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#   8%|▊         | 17/200 [00:19<01:39,  1.84it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#   9%|▉         | 18/200 [00:21<02:25,  1.25it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  10%|▉         | 19/200 [00:21<01:50,  1.64it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  10%|█         | 20/200 [00:21<01:28,  2.03it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  10%|█         | 21/200 [00:21<01:19,  2.26it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  11%|█         | 22/200 [00:22<01:14,  2.40it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  12%|█▏        | 23/200 [00:22<01:05,  2.72it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  12%|█▏        | 24/200 [01:01<35:15, 12.02s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  12%|█▎        | 25/200 [01:01<24:39,  8.45s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  13%|█▎        | 26/200 [01:02<17:26,  6.01s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  14%|█▎        | 27/200 [01:02<12:22,  4.29s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  14%|█▍        | 28/200 [01:02<08:50,  3.08s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  14%|█▍        | 29/200 [01:03<06:26,  2.26s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  15%|█▌        | 30/200 [01:03<04:41,  1.66s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  16%|█▌        | 31/200 [01:03<03:24,  1.21s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  16%|█▌        | 32/200 [01:03<02:34,  1.09it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  16%|█▋        | 33/200 [01:03<01:58,  1.40it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  17%|█▋        | 34/200 [01:05<02:20,  1.18it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  18%|█▊        | 35/200 [01:05<01:49,  1.50it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  18%|█▊        | 36/200 [01:05<01:25,  1.92it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  18%|█▊        | 37/200 [01:05<01:18,  2.07it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  19%|█▉        | 38/200 [01:06<01:04,  2.52it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  20%|█▉        | 39/200 [01:06<01:16,  2.12it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  20%|██        | 40/200 [01:07<01:04,  2.48it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  20%|██        | 41/200 [01:07<00:58,  2.74it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  21%|██        | 42/200 [01:07<00:53,  2.94it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  22%|██▏       | 43/200 [01:42<28:20, 10.83s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  22%|██▏       | 44/200 [01:43<19:49,  7.62s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  22%|██▎       | 45/200 [01:43<13:52,  5.37s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  23%|██▎       | 46/200 [01:43<09:49,  3.83s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  24%|██▎       | 47/200 [01:43<06:57,  2.73s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  24%|██▍       | 48/200 [01:43<04:59,  1.97s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  24%|██▍       | 49/200 [01:43<03:34,  1.42s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  25%|██▌       | 50/200 [01:44<02:36,  1.05s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  26%|██▌       | 51/200 [01:44<01:54,  1.30it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  26%|██▌       | 52/200 [01:44<01:24,  1.76it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
# C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  27%|██▋       | 54/200 [01:44<00:52,  2.80it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  28%|██▊       | 55/200 [01:44<00:42,  3.38it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
# C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  28%|██▊       | 57/200 [01:44<00:28,  4.94it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
# C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  30%|██▉       | 59/200 [01:45<00:27,  5.14it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  30%|███       | 60/200 [01:45<00:26,  5.20it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  30%|███       | 61/200 [01:45<00:29,  4.77it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  31%|███       | 62/200 [01:46<00:36,  3.76it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
# C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  32%|███▏      | 64/200 [01:46<00:29,  4.65it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  32%|███▎      | 65/200 [01:46<00:26,  5.18it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  33%|███▎      | 66/200 [01:46<00:24,  5.50it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  34%|███▎      | 67/200 [01:46<00:24,  5.42it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
# C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  34%|███▍      | 69/200 [01:47<00:20,  6.34it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  35%|███▌      | 70/200 [01:47<00:19,  6.70it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  36%|███▌      | 71/200 [01:47<00:18,  6.87it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  36%|███▌      | 72/200 [02:01<08:16,  3.88s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  36%|███▋      | 73/200 [02:01<06:04,  2.87s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  37%|███▋      | 74/200 [02:33<22:56, 10.92s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  38%|███▊      | 75/200 [02:33<16:19,  7.84s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  38%|███▊      | 76/200 [02:33<11:46,  5.70s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
# C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  39%|███▉      | 78/200 [02:34<06:26,  3.17s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  40%|███▉      | 79/200 [02:34<04:53,  2.42s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  40%|████      | 80/200 [02:34<03:40,  1.84s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  40%|████      | 81/200 [02:34<02:43,  1.38s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  41%|████      | 82/200 [02:34<02:07,  1.08s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  42%|████▏     | 83/200 [02:35<01:44,  1.12it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  42%|████▏     | 84/200 [02:35<01:18,  1.48it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  42%|████▎     | 85/200 [02:35<01:01,  1.86it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  43%|████▎     | 86/200 [02:36<00:58,  1.95it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  44%|████▎     | 87/200 [02:36<00:47,  2.38it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
# C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  44%|████▍     | 89/200 [02:36<00:30,  3.63it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  45%|████▌     | 90/200 [02:36<00:26,  4.12it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  46%|████▌     | 91/200 [02:36<00:23,  4.70it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
# C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  46%|████▋     | 93/200 [02:37<00:17,  5.95it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
# C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  48%|████▊     | 95/200 [02:37<00:15,  6.81it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  48%|████▊     | 96/200 [02:37<00:14,  7.15it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  48%|████▊     | 97/200 [02:37<00:15,  6.79it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  49%|████▉     | 98/200 [02:37<00:15,  6.76it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  50%|████▉     | 99/200 [02:37<00:14,  7.01it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
# C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  50%|█████     | 101/200 [02:37<00:11,  8.78it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
# C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  52%|█████▏    | 103/200 [02:38<00:10,  9.11it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  52%|█████▏    | 104/200 [02:38<00:11,  8.42it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  52%|█████▎    | 105/200 [02:38<00:12,  7.50it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
# C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  54%|█████▎    | 107/200 [02:38<00:11,  7.82it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  54%|█████▍    | 108/200 [02:38<00:11,  8.15it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  55%|█████▍    | 109/200 [02:38<00:11,  7.85it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  55%|█████▌    | 110/200 [02:39<00:13,  6.44it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  56%|█████▌    | 111/200 [02:39<00:13,  6.45it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  56%|█████▌    | 112/200 [02:39<00:16,  5.27it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  56%|█████▋    | 113/200 [02:39<00:15,  5.71it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  57%|█████▋    | 114/200 [02:39<00:13,  6.31it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
# C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  58%|█████▊    | 116/200 [02:40<00:12,  6.91it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  58%|█████▊    | 117/200 [02:40<00:11,  7.48it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  59%|█████▉    | 118/200 [02:55<05:39,  4.14s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  60%|█████▉    | 119/200 [02:56<04:12,  3.11s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
# C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  60%|██████    | 121/200 [02:56<02:23,  1.81s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  61%|██████    | 122/200 [02:56<01:52,  1.44s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  62%|██████▏   | 123/200 [02:56<01:25,  1.11s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  62%|██████▏   | 124/200 [02:57<01:11,  1.07it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  62%|██████▎   | 125/200 [02:57<00:54,  1.39it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  63%|██████▎   | 126/200 [03:11<05:37,  4.56s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  64%|██████▎   | 127/200 [03:11<04:01,  3.31s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  64%|██████▍   | 128/200 [03:12<02:52,  2.39s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  64%|██████▍   | 129/200 [03:12<02:05,  1.77s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  65%|██████▌   | 130/200 [03:12<01:31,  1.30s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  66%|██████▌   | 131/200 [03:13<01:18,  1.14s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
# C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  66%|██████▋   | 133/200 [03:13<00:44,  1.52it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  67%|██████▋   | 134/200 [03:13<00:34,  1.92it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  68%|██████▊   | 135/200 [03:37<07:07,  6.58s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  68%|██████▊   | 136/200 [03:37<05:10,  4.86s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  68%|██████▊   | 137/200 [03:37<03:42,  3.54s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  69%|██████▉   | 138/200 [03:37<02:38,  2.56s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  70%|██████▉   | 139/200 [03:39<02:14,  2.21s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  70%|███████   | 140/200 [03:39<01:36,  1.61s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  70%|███████   | 141/200 [03:39<01:11,  1.22s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  71%|███████   | 142/200 [03:39<00:51,  1.12it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  72%|███████▏  | 143/200 [03:39<00:37,  1.51it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  72%|███████▏  | 144/200 [03:40<00:27,  2.01it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  72%|███████▎  | 145/200 [03:54<04:14,  4.62s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  73%|███████▎  | 146/200 [04:24<11:00, 12.23s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
# C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  74%|███████▍  | 148/200 [04:27<06:21,  7.33s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  74%|███████▍  | 149/200 [04:28<04:54,  5.77s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  75%|███████▌  | 150/200 [04:28<03:34,  4.29s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  76%|███████▌  | 151/200 [04:58<09:12, 11.28s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  76%|███████▌  | 152/200 [05:13<09:42, 12.13s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  76%|███████▋  | 153/200 [05:13<06:59,  8.92s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  77%|███████▋  | 154/200 [05:14<04:52,  6.36s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  78%|███████▊  | 155/200 [05:14<03:24,  4.53s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
# C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  78%|███████▊  | 157/200 [05:14<01:48,  2.52s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  79%|███████▉  | 158/200 [05:14<01:21,  1.94s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  80%|███████▉  | 159/200 [05:14<01:01,  1.50s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  80%|████████  | 160/200 [05:14<00:45,  1.15s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  80%|████████  | 161/200 [05:15<00:33,  1.15it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  81%|████████  | 162/200 [05:15<00:26,  1.42it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  82%|████████▏ | 163/200 [05:15<00:20,  1.76it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  82%|████████▏ | 164/200 [05:15<00:15,  2.28it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
# C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  83%|████████▎ | 166/200 [05:16<00:10,  3.23it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
# C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  84%|████████▍ | 168/200 [05:16<00:07,  4.02it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  84%|████████▍ | 169/200 [05:16<00:06,  4.54it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
# C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  86%|████████▌ | 171/200 [05:30<01:24,  2.91s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  86%|████████▌ | 172/200 [06:06<04:36,  9.89s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
# C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  87%|████████▋ | 174/200 [06:06<02:40,  6.15s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  88%|████████▊ | 175/200 [06:06<02:02,  4.88s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  88%|████████▊ | 176/200 [06:06<01:30,  3.76s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  88%|████████▊ | 177/200 [06:07<01:06,  2.91s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  89%|████████▉ | 178/200 [06:07<00:49,  2.23s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  90%|████████▉ | 179/200 [06:07<00:36,  1.74s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  90%|█████████ | 180/200 [06:08<00:26,  1.32s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  90%|█████████ | 181/200 [06:08<00:19,  1.04s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  91%|█████████ | 182/200 [06:08<00:15,  1.17it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  92%|█████████▏| 183/200 [06:08<00:11,  1.50it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  92%|█████████▏| 184/200 [06:09<00:08,  1.88it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  92%|█████████▎| 185/200 [06:09<00:06,  2.27it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  93%|█████████▎| 186/200 [06:09<00:04,  2.81it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
# C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  94%|█████████▍| 188/200 [06:09<00:02,  4.04it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  94%|█████████▍| 189/200 [06:10<00:02,  4.14it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  95%|█████████▌| 190/200 [06:11<00:05,  1.73it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  96%|█████████▌| 191/200 [06:11<00:04,  2.18it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
# C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  96%|█████████▋| 193/200 [06:11<00:02,  3.20it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  97%|█████████▋| 194/200 [06:12<00:01,  3.21it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  98%|█████████▊| 195/200 [06:12<00:01,  3.64it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  98%|█████████▊| 196/200 [06:12<00:00,  4.22it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
# C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  99%|█████████▉| 198/200 [06:12<00:00,  6.05it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
# 100%|█████████▉| 199/200 [06:12<00:00,  6.46it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_60836\3065519366.py:27: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
# 100%|██████████| 200/200 [06:13<00:00,  1.87s/it]
#         date  ticker  close
# 0 2015-01-31  005930  27300
# 1 2015-02-28  005930  27140
# 2 2015-03-31  005930  28820
# 3 2015-04-30  005930  28200
# 4 2015-05-31  005930  26140

# %%
import FinanceDataReader as fdr
import pandas as pd
from tqdm import tqdm

df_price = pd.read_csv("kospi200_fdr_prices_monthly.csv")

# %%
# 월말 가격을 피벗
price_pivot = df_price.pivot(index='date', columns='ticker', values='close').sort_index()
price_pivot.head()
# Out:
# ticker       80       100       120      150      155      240      270     \
# date
# 2015-01-31  23250.0  24107.0  191500.0  81925.0  50123.0  25200.0  46000.0
# 2015-02-28  22850.0  24107.0  181000.0  94134.0  55049.0  23700.0  45500.0
# 2015-03-31  22200.0  26365.0  195000.0  91771.0  56000.0  21100.0  45200.0
# 2015-04-30  22700.0  32568.0  204500.0  98073.0  60667.0  21250.0  49600.0
# 2015-05-31  21400.0  37644.0  188000.0  90196.0  59802.0  19650.0  47650.0
#
# ticker       660      720       810     ...  383220  395400  402340  443060  \
# date                                    ...
# 2015-01-31  47650.0  42470.0  295000.0  ...     NaN     NaN     NaN     NaN
# 2015-02-28  46600.0  48065.0  255000.0  ...     NaN     NaN     NaN     NaN
# 2015-03-31  45550.0  49038.0  267500.0  ...     NaN     NaN     NaN     NaN
# 2015-04-30  46150.0  50497.0  282500.0  ...     NaN     NaN     NaN     NaN
# 2015-05-31  51100.0  43054.0  304000.0  ...     NaN     NaN     NaN     NaN
#
# ticker      450080  454910  457190  462870  484870  489790
# date
# 2015-01-31     NaN     NaN     NaN     NaN     NaN     NaN
# 2015-02-28     NaN     NaN     NaN     NaN     NaN     NaN
# 2015-03-31     NaN     NaN     NaN     NaN     NaN     NaN
# 2015-04-30     NaN     NaN     NaN     NaN     NaN     NaN
# 2015-05-31     NaN     NaN     NaN     NaN     NaN     NaN
#
# [5 rows x 196 columns]

# %% [markdown]
# ### **Step 3. Implementation of the Reversal Momentum Strategy**

# %%
# 수익률 계산: t / t-1 - 1
ret_1m = price_pivot.pct_change(periods=1)
ret_3m = price_pivot.pct_change(periods=3)

# %%
# Z-score 표준화
def zscore(df):
    return (df - df.mean(axis=1, skipna=True).values[:, None]) / df.std(axis=1, skipna=True).values[:, None]

score = -zscore(ret_1m) - 0.5 * zscore(ret_3m)  # 낙폭 클수록 점수 높음
score.head()
# Out:
# ticker        80        100       120       150       155       240     \
# date
# 2015-01-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2015-02-28       NaN       NaN       NaN       NaN       NaN       NaN
# 2015-03-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2015-04-30  0.648648 -1.850818  0.270436 -0.109956 -0.262776  0.994113
# 2015-05-31  0.698190 -1.695367  0.738642  0.840813  0.184315  0.971723
#
# ticker        270       660       720       810     ...  383220  395400  \
# date                                                ...
# 2015-01-31       NaN       NaN       NaN       NaN  ...     NaN     NaN
# 2015-02-28       NaN       NaN       NaN       NaN  ...     NaN     NaN
# 2015-03-31       NaN       NaN       NaN       NaN  ...     NaN     NaN
# 2015-04-30 -0.184095  0.745090  0.253513  0.375174  ...     NaN     NaN
# 2015-05-31  0.420910 -0.729455  1.419183 -0.623151  ...     NaN     NaN
#
# ticker      402340  443060  450080  454910  457190  462870  484870  489790
# date
# 2015-01-31     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2015-02-28     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2015-03-31     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2015-04-30     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2015-05-31     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# [5 rows x 196 columns]

# %%
# KOSPI200 벤치마크
benchmark_daily = fdr.DataReader('KS200', start='2015-01-01', end='2024-12-31')
benchmark = benchmark_daily['Close'].resample('M').last()
benchmark.name = 'KOSPI200'
# Out:
# C:\Users\shinw\AppData\Local\Temp\ipykernel_60048\1415621465.py:3: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   benchmark = benchmark_daily['Close'].resample('M').last()

# %%
# 파라미터 설정
n_holdings = 20             # 포트폴리오 종목 수
lookback_months = 24        # 시장 상태 판단 기간

strategy_returns = []       
strategy_dates = []

# %%
for i in range(lookback_months, len(score) - 1):
    current_date = score.index[i]
    next_date = score.index[i + 1]

    # 시장 상태 판단: 벤치마크 24개월 수익률
    try:
        market_return = benchmark.loc[current_date] / benchmark.loc[score.index[i - lookback_months]] - 1
    except KeyError:
        continue

    market_state = 'UP' if market_return > 0 else 'DOWN'

    # 종목 선택
    if market_state == 'UP':
        current_momentum = ret_1m.iloc[i]
        selected = current_momentum.sort_values(ascending=False).head(n_holdings).index
    else:
        current_score = score.iloc[i]
        selected = current_score.sort_values(ascending=False).head(n_holdings).index

    # 다음 달 수익률 계산
    next_return = ret_1m.iloc[i + 1][selected].mean()
    strategy_returns.append(next_return)
    strategy_dates.append(next_date)

# %%
result = pd.DataFrame({
    'date': strategy_dates,
    'strategy': strategy_returns
}).set_index('date')

result['cum_strategy'] = (1 + result['strategy']).cumprod()

# 벤치마크 및 전략 누적 수익률
benchmark_ret = benchmark.pct_change()
result['benchmark'] = benchmark_ret.reindex(result.index)
result['cum_benchmark'] = (1 + result['benchmark']).cumprod()

# %%
result.index = pd.to_datetime(result.index)

# %%
def calculate_cagr(series):
    years = (series.index[-1] - series.index[0]).days / 365.25
    return series.iloc[-1]**(1/years) - 1

cagr_strategy = calculate_cagr(result['cum_strategy'])
cagr_benchmark = calculate_cagr(result['cum_benchmark'])

# %%
print(f"Reversal Momentum Strategy 누적 수익률: {result['cum_strategy'].iloc[-1]:.4f}")
print(f"벤치마크 누적 수익률: {result['cum_benchmark'].iloc[-1]:.4f}")
print(f"Reversal Momentum Strategy CAGR: {cagr_strategy:.4f}")
print(f"벤치마크 CAGR: {cagr_benchmark:.4f}")
# Out:
# Reversal Momentum Strategy 누적 수익률: 2.1973
# 벤치마크 누적 수익률: 1.1855
# Reversal Momentum Strategy CAGR: 0.1056
# 벤치마크 CAGR: 0.0219

# %% [markdown]
# ### ***) Preventing Korean Font Corruption**

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import platform

# 한글 폰트
if platform.system() == 'Windows':
    plt.rcParams['font.family'] = 'Malgun Gothic'
elif platform.system() == 'Darwin':  # macOS
    plt.rcParams['font.family'] = 'AppleGothic'
else:  # Linux
    plt.rcParams['font.family'] = 'NanumGothic'

# 마이너스 깨짐 방지
plt.rcParams['axes.unicode_minus'] = False

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(result.index, result['cum_strategy'], label='시장상태 기반 전략')
plt.plot(result.index, result['cum_benchmark'], label='KOSPI200 벤치마크')
plt.xlabel('Date')
plt.ylabel('Cumulative Return')
plt.title('Reversal Momentum Strategy vs KOSPI200')
plt.legend()
plt.grid(True)
plt.show()

# %%
result.index = pd.to_datetime(result.index)

# 누적 수익률
final_strategy = result['cum_strategy'].iloc[-1]
final_benchmark = result['cum_benchmark'].iloc[-1]

print(f"Reversal Momentum Strategy 누적 수익률: {final_strategy - 1:.2%}")
print(f"KOSPI200 누적 수익률   : {final_benchmark - 1:.2%}")
# Out:
# Momentum Reversal 전략 누적 수익률: 119.73%
# KOSPI200 누적 수익률   : 18.55%

# %%
def calculate_max_drawdown(series):
    # 고점 누적
    rolling_max = series.cummax()
    # 고점 대비 하락률
    drawdown = series / rolling_max - 1.0
    # 최댓값 =가장 큰 낙폭
    max_drawdown = drawdown.min()
    return max_drawdown

mdd_strategy = calculate_max_drawdown(result['cum_strategy'])
mdd_benchmark = calculate_max_drawdown(result['cum_benchmark'])

print("Strategy Max Drawdown:", mdd_strategy)
print("Benchmark Max Drawdown:", mdd_benchmark)
# Out:
# Strategy Max Drawdown: -0.5088999454936605
# Benchmark Max Drawdown: -0.35885516361316183

# %%
import matplotlib.pyplot as plt

def plot_drawdown(cum_wealth, label="Strategy"):
    rolling_max = cum_wealth.cummax()
    drawdown = cum_wealth / rolling_max - 1.0
    plt.plot(drawdown, label=label)
    return drawdown

plt.figure(figsize=(10,4))
plot_drawdown(result['cum_strategy'], "Strategy")
plot_drawdown(result['cum_benchmark'], "Benchmark")
plt.title("Drawdown")
plt.ylabel("Drawdown")
plt.xlabel("")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import numpy as np

def infer_periods_per_year(index):
    avg_days = np.median(np.diff(index.values).astype('timedelta64[D]').astype(int))
    if avg_days <= 2:
        return 252
    elif avg_days <= 10:
        return 52
    elif avg_days <= 40:
        return 12
    else:
        return 1

def calculate_sharpe_ratio(cum_wealth, risk_free_rate_annual=0.0):
    returns = cum_wealth.pct_change().dropna()
    periods_per_year = infer_periods_per_year(cum_wealth.index)
    rf_periodic = (1 + risk_free_rate_annual)**(1/periods_per_year) - 1
    excess = returns - rf_periodic
    mu_ann = excess.mean() * periods_per_year
    vol_ann = excess.std(ddof=1) * np.sqrt(periods_per_year)
    return mu_ann / vol_ann if vol_ann != 0 else np.nan

sharpe_strategy  = calculate_sharpe_ratio(result['cum_strategy'])
sharpe_benchmark = calculate_sharpe_ratio(result['cum_benchmark'])

print("Sharpe Ratio (Strategy):", sharpe_strategy)
print("Sharpe Ratio (Benchmark):", sharpe_benchmark)
# Out:
# Sharpe Ratio (Strategy): 0.4939932361715361
# Sharpe Ratio (Benchmark): 0.20445811924410862

# %% [markdown]
# ### **Limitations and Potential Biases of the Strategy**
# **1) Transaction Costs Ignored**
#
# The strategy assumes frictionless trading by ignoring real-world transaction costs such as commissions, taxes, and slippage incurred during monthly rebalancing. In practice, these costs can accumulate and significantly reduce net returns. Without incorporating even modest cost estimates (e.g., 0.3%–0.5% per trade), the backtest is likely to overstate the strategy's performance.
#
# **2) Mismatch in Benchmark Weighting Method**
#
# The KOSPI200 benchmark is market-cap weighted, whereas the strategy uses an equal-weighted portfolio. This difference in methodology leads to a natural bias toward smaller-cap stocks in the strategy, which can exaggerate outperformance when compared to a large-cap weighted index. For a more accurate evaluation, either the strategy should be benchmarked against an equal-weighted index or adjusted to reflect market-cap weighting.
#
# **3) Lag in Market Regime Classification**
#
# The strategy defines market regimes based on trailing 24-month cumulative returns, which is inherently a backward-looking approach. As a result, regime shifts may be detected too late, reducing the effectiveness of timely strategy switching. In volatile or rapidly changing markets, this lag could undermine the benefits of dynamic allocation. More responsive indicators or complementary forward-looking signals may be needed to improve regime detection.
#
# **4) Limited Downside Protection**
# Although the strategy achieves a higher Sharpe ratio compared to the benchmark, the drawdown analysis reveals that it does not effectively protect against market downturns. Large declines are still observed, indicating that while the strategy improves risk-adjusted returns, it lacks strong downside defense. This limitation is particularly important for investors who prioritize capital preservation during periods of market stress.

# %% [markdown]
# ### **Step 4. Market Capitalization Weighting**

# %%
# 분석 기간 설정
start = '2015-01-01'
end = '2024-12-31'

kospi = fdr.StockListing('KOSPI')

# KOSPI200
kospi200_like = kospi.sort_values(by='Marcap', ascending=False).head(200)
tickers = kospi200_like['Code'].tolist()

# %%
df_all = fdr.StockListing('KOSPI')

kospi200_like = df_all.sort_values(by='Marcap', ascending=False).head(200)
kospi200_like = kospi200_like[['Code', 'Name']]
kospi200_like.columns = ['ticker', 'name']

# 분석 기간 설정
start_date = '2015-01-01'
end_date = '2024-12-31'

price_list = []

for _, row in tqdm(kospi200_like.iterrows(), total=len(kospi200_like)):
    code = row['ticker']
    try:
        df = fdr.DataReader(code, start=start_date, end=end_date)
        df = df[['Close']].copy()
        df.index.name = 'date'
        df['ticker'] = code

        # 상장주식 수로 시가총액 계산 -> 시가총액 계산을 수동으로 함
        shares = df_all[df_all['Code'] == code]['Stocks'].values[0]
        df['Marcap'] = df['Close'] * shares

        df = df.reset_index()
        df['date'] = pd.to_datetime(df['date'])
        df = df.set_index('date').resample('M').last().dropna().reset_index()
        price_list.append(df)

    except Exception as e:
        print(f"[{code}] 에러: {e}")
        continue

df_price = pd.concat(price_list)
df_price = df_price[['date', 'ticker', 'Close', 'Marcap']]
df_price.columns = ['date', 'ticker', 'close', 'marcap']
df_price.to_csv("kospi200_fdr_prices_monthly.csv", index=False)
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#   0%|          | 1/200 [00:11<37:27, 11.29s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#   1%|          | 2/200 [00:11<15:34,  4.72s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#   2%|▏         | 3/200 [00:11<08:36,  2.62s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#   2%|▏         | 4/200 [00:11<05:32,  1.70s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#   2%|▎         | 5/200 [00:19<12:14,  3.77s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#   3%|▎         | 6/200 [00:20<09:25,  2.91s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#   4%|▎         | 7/200 [00:20<06:24,  1.99s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#   4%|▍         | 8/200 [00:20<04:38,  1.45s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#   4%|▍         | 9/200 [00:21<03:20,  1.05s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#   5%|▌         | 10/200 [00:21<02:23,  1.32it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#   6%|▌         | 11/200 [00:21<01:45,  1.80it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#   6%|▌         | 12/200 [00:21<01:28,  2.13it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#   6%|▋         | 13/200 [00:21<01:12,  2.58it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#   7%|▋         | 14/200 [00:21<00:57,  3.22it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
# C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#   8%|▊         | 16/200 [00:22<00:43,  4.25it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#   8%|▊         | 17/200 [00:22<00:42,  4.29it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#   9%|▉         | 18/200 [00:22<00:40,  4.53it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  10%|▉         | 19/200 [00:22<00:38,  4.72it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  10%|█         | 20/200 [00:22<00:33,  5.30it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  10%|█         | 21/200 [01:06<37:34, 12.60s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  11%|█         | 22/200 [01:06<26:41,  9.00s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  12%|█▏        | 23/200 [01:06<18:58,  6.43s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  12%|█▏        | 24/200 [01:07<13:28,  4.60s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  12%|█▎        | 25/200 [01:07<09:53,  3.39s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  13%|█▎        | 26/200 [01:07<07:09,  2.47s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  14%|█▎        | 27/200 [01:09<05:59,  2.08s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  14%|█▍        | 28/200 [01:09<04:19,  1.51s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
# C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  15%|█▌        | 30/200 [01:09<02:27,  1.15it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  16%|█▌        | 31/200 [01:43<25:39,  9.11s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  16%|█▌        | 32/200 [01:43<18:55,  6.76s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  16%|█▋        | 33/200 [01:44<13:54,  5.00s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  17%|█▋        | 34/200 [01:44<10:05,  3.65s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  18%|█▊        | 35/200 [01:45<08:26,  3.07s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
# C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  18%|█▊        | 37/200 [01:48<05:59,  2.21s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  19%|█▉        | 38/200 [01:48<04:35,  1.70s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  20%|█▉        | 39/200 [01:48<03:27,  1.29s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  20%|██        | 40/200 [02:17<23:44,  8.90s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  20%|██        | 41/200 [02:18<17:15,  6.51s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  21%|██        | 42/200 [02:18<12:26,  4.73s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  22%|██▏       | 43/200 [02:18<09:01,  3.45s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
# C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  22%|██▎       | 45/200 [02:59<28:40, 11.10s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  23%|██▎       | 46/200 [03:00<22:12,  8.65s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  24%|██▎       | 47/200 [03:00<16:31,  6.48s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  24%|██▍       | 48/200 [03:01<12:05,  4.77s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
# C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  25%|██▌       | 50/200 [03:01<06:57,  2.78s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
# C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  26%|██▌       | 52/200 [03:02<04:54,  1.99s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  26%|██▋       | 53/200 [03:03<04:03,  1.66s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  27%|██▋       | 54/200 [03:04<03:57,  1.63s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  28%|██▊       | 55/200 [03:04<03:02,  1.26s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  28%|██▊       | 56/200 [03:05<02:17,  1.04it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
# C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  29%|██▉       | 58/200 [03:05<01:24,  1.68it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  30%|██▉       | 59/200 [03:05<01:08,  2.05it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  30%|███       | 60/200 [03:06<01:21,  1.71it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  30%|███       | 61/200 [03:06<01:05,  2.14it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  31%|███       | 62/200 [03:06<00:51,  2.69it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  32%|███▏      | 63/200 [03:06<00:41,  3.30it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  32%|███▏      | 64/200 [03:06<00:38,  3.53it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  32%|███▎      | 65/200 [03:37<20:21,  9.05s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  33%|███▎      | 66/200 [03:37<14:25,  6.46s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  34%|███▎      | 67/200 [03:37<10:15,  4.63s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  34%|███▍      | 68/200 [03:38<07:31,  3.42s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  34%|███▍      | 69/200 [03:38<05:19,  2.44s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  35%|███▌      | 70/200 [03:38<03:47,  1.75s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
# C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  36%|███▌      | 72/200 [03:39<02:17,  1.07s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  36%|███▋      | 73/200 [03:39<01:48,  1.17it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  37%|███▋      | 74/200 [03:40<01:54,  1.10it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  38%|███▊      | 75/200 [04:16<21:50, 10.48s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  38%|███▊      | 76/200 [04:17<15:59,  7.74s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  38%|███▊      | 77/200 [04:17<11:24,  5.56s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  39%|███▉      | 78/200 [04:17<08:08,  4.01s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  40%|███▉      | 79/200 [04:49<24:43, 12.26s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  40%|████      | 80/200 [05:00<23:25, 11.72s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  40%|████      | 81/200 [05:00<16:26,  8.29s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  41%|████      | 82/200 [05:00<11:33,  5.88s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  42%|████▏     | 83/200 [05:00<08:07,  4.17s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  42%|████▏     | 84/200 [05:00<05:44,  2.97s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  42%|████▎     | 85/200 [05:01<04:14,  2.21s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  43%|████▎     | 86/200 [05:01<03:01,  1.59s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  44%|████▎     | 87/200 [05:01<02:10,  1.15s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  44%|████▍     | 88/200 [05:01<01:34,  1.18it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  44%|████▍     | 89/200 [05:03<01:58,  1.07s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  45%|████▌     | 90/200 [05:03<01:26,  1.27it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  46%|████▌     | 91/200 [05:03<01:04,  1.69it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  46%|████▌     | 92/200 [05:03<00:50,  2.13it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
# C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  47%|████▋     | 94/200 [05:03<00:32,  3.30it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  48%|████▊     | 95/200 [05:04<00:27,  3.88it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  48%|████▊     | 96/200 [05:04<00:23,  4.38it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  48%|████▊     | 97/200 [05:04<00:24,  4.26it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  49%|████▉     | 98/200 [05:04<00:22,  4.50it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  50%|████▉     | 99/200 [05:05<00:25,  3.91it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  50%|█████     | 100/200 [05:35<15:02,  9.02s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  50%|█████     | 101/200 [05:35<10:35,  6.42s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  51%|█████     | 102/200 [05:35<07:30,  4.60s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  52%|█████▏    | 103/200 [05:36<05:17,  3.27s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
# C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  52%|█████▎    | 105/200 [05:36<02:53,  1.83s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  53%|█████▎    | 106/200 [05:36<02:11,  1.40s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
# C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  54%|█████▍    | 108/200 [05:36<01:18,  1.17it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  55%|█████▍    | 109/200 [05:36<01:02,  1.46it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  55%|█████▌    | 110/200 [05:36<00:51,  1.74it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
# C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  56%|█████▌    | 112/200 [05:37<00:33,  2.65it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  56%|█████▋    | 113/200 [05:37<00:32,  2.67it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  57%|█████▋    | 114/200 [05:37<00:28,  3.00it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  57%|█████▊    | 115/200 [05:37<00:25,  3.34it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  58%|█████▊    | 116/200 [05:37<00:20,  4.05it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  58%|█████▊    | 117/200 [05:38<00:23,  3.58it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  59%|█████▉    | 118/200 [05:38<00:20,  4.05it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  60%|█████▉    | 119/200 [06:11<13:18,  9.85s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  60%|██████    | 120/200 [06:12<09:22,  7.03s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  60%|██████    | 121/200 [06:12<06:45,  5.13s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  61%|██████    | 122/200 [06:12<04:46,  3.67s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  62%|██████▏   | 123/200 [06:13<03:22,  2.63s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  62%|██████▏   | 124/200 [07:00<20:09, 15.92s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  62%|██████▎   | 125/200 [07:00<14:01, 11.22s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  63%|██████▎   | 126/200 [07:01<09:55,  8.04s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  64%|██████▎   | 127/200 [07:01<06:54,  5.68s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  64%|██████▍   | 128/200 [07:01<04:52,  4.07s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  64%|██████▍   | 129/200 [07:01<03:25,  2.90s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
# C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  66%|██████▌   | 131/200 [07:01<01:50,  1.60s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  66%|██████▌   | 132/200 [07:02<01:25,  1.26s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  66%|██████▋   | 133/200 [07:02<01:05,  1.02it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  67%|██████▋   | 134/200 [07:02<00:57,  1.14it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  68%|██████▊   | 135/200 [07:02<00:42,  1.51it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  68%|██████▊   | 136/200 [07:03<00:32,  1.96it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  68%|██████▊   | 137/200 [07:03<00:25,  2.49it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
# C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  70%|██████▉   | 139/200 [07:03<00:16,  3.77it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  70%|███████   | 140/200 [07:03<00:13,  4.32it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  70%|███████   | 141/200 [07:03<00:12,  4.77it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  71%|███████   | 142/200 [07:37<08:59,  9.30s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  72%|███████▏  | 143/200 [07:37<06:25,  6.76s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  72%|███████▏  | 144/200 [07:37<04:32,  4.87s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  72%|███████▎  | 145/200 [07:38<03:12,  3.51s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  73%|███████▎  | 146/200 [07:38<02:16,  2.53s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  74%|███████▎  | 147/200 [07:38<01:36,  1.82s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  74%|███████▍  | 148/200 [07:38<01:10,  1.36s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
# C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  75%|███████▌  | 150/200 [07:39<00:45,  1.11it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  76%|███████▌  | 151/200 [07:39<00:34,  1.41it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  76%|███████▌  | 152/200 [07:39<00:27,  1.77it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  76%|███████▋  | 153/200 [07:39<00:21,  2.16it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  77%|███████▋  | 154/200 [07:39<00:17,  2.68it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  78%|███████▊  | 155/200 [07:41<00:29,  1.54it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  78%|███████▊  | 156/200 [07:41<00:21,  2.03it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  78%|███████▊  | 157/200 [08:15<07:22, 10.28s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  79%|███████▉  | 158/200 [08:15<05:06,  7.30s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  80%|███████▉  | 159/200 [08:15<03:32,  5.18s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  80%|████████  | 160/200 [08:15<02:26,  3.67s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  80%|████████  | 161/200 [08:15<01:41,  2.61s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  81%|████████  | 162/200 [08:16<01:11,  1.87s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  82%|████████▏ | 163/200 [08:16<00:49,  1.35s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  82%|████████▏ | 164/200 [08:16<00:35,  1.01it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
# C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  83%|████████▎ | 166/200 [08:16<00:19,  1.73it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  84%|████████▎ | 167/200 [08:16<00:15,  2.14it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  84%|████████▍ | 168/200 [08:16<00:12,  2.63it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  84%|████████▍ | 169/200 [08:16<00:10,  3.02it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  85%|████████▌ | 170/200 [08:17<00:08,  3.38it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  86%|████████▌ | 171/200 [08:17<00:07,  3.80it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  86%|████████▌ | 172/200 [08:17<00:06,  4.24it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  86%|████████▋ | 173/200 [08:31<01:56,  4.33s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  87%|████████▋ | 174/200 [08:52<04:02,  9.33s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  88%|████████▊ | 175/200 [08:53<02:44,  6.59s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  88%|████████▊ | 176/200 [08:53<01:53,  4.74s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  88%|████████▊ | 177/200 [08:53<01:17,  3.36s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  89%|████████▉ | 178/200 [08:53<00:52,  2.39s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  90%|████████▉ | 179/200 [09:08<02:05,  5.98s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  90%|█████████ | 180/200 [09:08<01:28,  4.40s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  90%|█████████ | 181/200 [09:09<01:00,  3.17s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  91%|█████████ | 182/200 [09:09<00:44,  2.49s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  92%|█████████▏| 183/200 [09:18<01:14,  4.40s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  92%|█████████▏| 184/200 [09:33<01:58,  7.38s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  92%|█████████▎| 185/200 [09:33<01:18,  5.23s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  93%|█████████▎| 186/200 [09:33<00:53,  3.81s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
# C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  94%|█████████▍| 188/200 [09:34<00:25,  2.11s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  94%|█████████▍| 189/200 [09:48<00:56,  5.12s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  95%|█████████▌| 190/200 [09:48<00:38,  3.82s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  96%|█████████▌| 191/200 [09:56<00:44,  4.91s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
# C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  96%|█████████▋| 193/200 [09:56<00:19,  2.82s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
# C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  98%|█████████▊| 195/200 [09:56<00:08,  1.78s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  98%|█████████▊| 196/200 [09:57<00:06,  1.57s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
# C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
#  99%|█████████▉| 198/200 [09:57<00:02,  1.02s/it]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
# 100%|█████████▉| 199/200 [09:58<00:00,  1.20it/s]C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4174433963.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.set_index('date').resample('M').last().dropna().reset_index()
# 100%|██████████| 200/200 [09:58<00:00,  2.99s/it]

# %%
df_price = pd.read_csv("kospi200_fdr_prices_monthly.csv")

# %%
# 피벗 테이블
price_pivot = df_price.pivot(index='date', columns='ticker', values='close').sort_index()
marcap_pivot = df_price.pivot(index='date', columns='ticker', values='marcap').sort_index()

ret_1m = price_pivot.pct_change(periods=1)
ret_3m = price_pivot.pct_change(periods=3)

# %%
def zscore(df):
    return (df - df.mean(axis=1, skipna=True).values[:, None]) / df.std(axis=1, skipna=True).values[:, None]

score = -zscore(ret_1m) - 0.5 * zscore(ret_3m)  # 낙폭 큰 종목 우선

# %%
import FinanceDataReader as fdr

# 벤치마크
benchmark_daily = fdr.DataReader('KS200', start='2015-01-01', end='2024-12-31')
benchmark = benchmark_daily['Close'].resample('M').last()
benchmark.name = 'KOSPI200'

# 24개월 수익률로 시장상황 판단
market_state = benchmark.pct_change(periods=24)
is_bull = market_state > 0
# Out:
# C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\3037276010.py:5: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   benchmark = benchmark_daily['Close'].resample('M').last()

# %%
n_stocks = 20

portfolio_weights = pd.DataFrame(index=score.index, columns=score.columns)

for date in score.index:
    if date not in is_bull:
        continue

    if is_bull.loc[date]:  # Bull market → 모멘텀
        selected = score.loc[date].nlargest(n_stocks).index
    else:  # Bear market → 리버설
        selected = score.loc[date].nsmallest(n_stocks).index

    # 시가총액 기준 가중치
    weights = marcap_pivot.loc[date, selected]
    weights = weights / weights.sum()
    portfolio_weights.loc[date, selected] = weights

# %%
future_ret = price_pivot.pct_change().shift(-1)
strategy_ret = (portfolio_weights * future_ret).sum(axis=1)

# %%
result = pd.DataFrame({
    'Strategy': (1 + strategy_ret).cumprod(),
    'KOSPI200': (1 + benchmark.pct_change()).cumprod()
})

def calculate_cagr(series):
    years = (series.index[-1] - series.index[0]).days / 365.25
    return series.iloc[-1]**(1/years) - 1

cagr_strategy = calculate_cagr(result['Strategy'])
cagr_benchmark = calculate_cagr(result['KOSPI200'])

print(f"Market-Cap Weighted Reversal Momentum Strategy 누적 수익률: {result['Strategy'].iloc[-1]:.4f}")
print(f"벤치마크 누적 수익률: {result['KOSPI200'].iloc[-1]:.4f}")
print(f"Market-Cap Weighted Reversal Momentum Strategy CAGR: {cagr_strategy:.4f}")
print(f"벤치마크 CAGR: {cagr_benchmark:.4f}")
# Out:
# Market-Cap Weighted Reversal Momentum Strategy 누적 수익률: 1.2390
# 벤치마크 누적 수익률: 1.2719
# Market-Cap Weighted Reversal Momentum Strategy CAGR: 0.0218
# 벤치마크 CAGR: 0.0245

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 6))
plt.plot(result.index, result['Strategy'], label='Momentum-Reversal Strategy (Cap-Weighted)')
plt.plot(result.index, result['KOSPI200'], label='KOSPI200')
plt.legend()
plt.title("Market-Cap Weighted Reversal Momentum Strategy vs KOSPI200")
plt.grid(True)
plt.show()

# %%
print(f"Market-Cap Weighted Reversal Momentum Strategy 누적 수익률   : {(result['Strategy'].iloc[-1] - 1)*100:.2f}%")
print(f"벤치마크 누적 수익률: {(result['KOSPI200'].iloc[-1] - 1)*100:.2f}%")
print(f"Market-Cap Weighted Reversal Momentum Strategy CAGR          : {cagr_strategy*100:.2f}%")
print(f"벤치마크 CAGR      : {cagr_benchmark*100:.2f}%")
# Out:
# Market-Cap Weighted Reversal Momentum Strategy 누적 수익률   : 23.90%
# 벤치마크 누적 수익률: 27.19%
# Market-Cap Weighted Reversal Momentum Strategy CAGR          : 2.18%
# 벤치마크 CAGR      : 2.45%

# %% [markdown]
# ### **Why Is the Market-Cap Weighted Reversal Momentum Strategy Underperforming?**
#
# **1️) Weaker Reversal Effects in Large-Cap Stocks**
#
# Reversal strategies typically rely on short-term price overreactions, where stocks that have declined significantly tend to rebound. However, large-cap stocks—which dominate in a market-cap weighted portfolio—tend to be more efficiently priced due to faster information dissemination and greater investor attention. This means that the price anomalies reversal strategies exploit are weaker or absent in large-cap names.
#
# **2) Structural Overlap with Benchmark & Reduced Diversification**
#
# Since the KOSPI200 index is already market-cap weighted, and heavily concentrated in a few large-cap stocks like Samsung Electronics and SK Hynix, a market-cap weighted reversal strategy ends up holding very similar exposures to the benchmark. At the same time, equal-weighted portfolios benefit from broader diversification, giving more weight to mid- and small-cap stocks where reversal effects are typically stronger. In contrast, market-cap weighted portfolios concentrate on large caps, limiting exposure to reversal opportunities and reducing portfolio differentiation.

# %% [markdown]
# ### **Step 5. Portfolio Construction with Strategic Asset Allocation**

# %%
# KODEX 국고채3년 ETF
bond = fdr.DataReader('114260', start='2015-01-01', end='2024-12-31')
bond_monthly = bond['Close'].resample('M').last()
bond_ret = bond_monthly.pct_change().dropna()
bond_ret.name = 'bond_ret'
# Out:
# C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\4022567458.py:3: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   bond_monthly = bond['Close'].resample('M').last()

# %%
combined_df = pd.concat([strategy_ret, bond_ret], axis=1).dropna()
combined_df.columns = ['strategy_ret', 'bond_ret']

# %%
# 70:30 자산배분 수익률
combined_df['portfolio_ret'] = 0.7 * combined_df['strategy_ret'] + 0.3 * combined_df['bond_ret']
combined_df['cum_portfolio'] = (1 + combined_df['portfolio_ret']).cumprod()
combined_df['cum_strategy'] = (1 + combined_df['strategy_ret']).cumprod()
combined_df['cum_bond'] = (1 + combined_df['bond_ret']).cumprod()

# %%
# 위와 동일한 함수 정의
def calculate_cagr(series):
    years = (series.index[-1] - series.index[0]).days / 365.25
    return series.iloc[-1]**(1/years) - 1

cagr_portfolio = calculate_cagr(combined_df['cum_portfolio'])
cagr_strategy = calculate_cagr(combined_df['cum_strategy'])
cagr_bond = calculate_cagr(combined_df['cum_bond'])

print(f"Reversal Momentum Strategy 누적 수익률: {combined_df['cum_strategy'].iloc[-1] - 1:.2%}")
print(f"국고채3년 ETF 누적 수익률: {combined_df['cum_bond'].iloc[-1] - 1:.2%}")
print(f"70/30 포트폴리오 누적 수익률: {combined_df['cum_portfolio'].iloc[-1] - 1:.2%}")
print(f"\nReversal Momentum Strategy CAGR: {cagr_strategy:.2%}")
print(f"채권 CAGR: {cagr_bond:.2%}")
print(f"70/30 포트폴리오 CAGR: {cagr_portfolio:.2%}")
# Out:
# Reversal Momentum Strategy 누적 수익률: 25.14%
# 국고채3년 ETF 누적 수익률: 18.87%
# 70/30 포트폴리오 누적 수익률: 30.90%
#
# Reversal Momentum Strategy CAGR: 2.31%
# 채권 CAGR: 1.77%
# 70/30 포트폴리오 CAGR: 2.77%

# %%
plt.figure(figsize=(12,6))
plt.plot(combined_df['cum_strategy'], label='Reversal Momentum Strategy (70%)', linestyle='--')
plt.plot(combined_df['cum_bond'], label='Treasury Bond ETF (30%)', linestyle='--')
plt.plot(combined_df['cum_portfolio'], label='70/30 Portfolio', linewidth=2)
plt.title('Fixed Allocation: 70% Reversal Strategy + 30% Bond ETF')
plt.ylabel('Cumulative Return')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\227849048.py:9: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) Malgun Gothic.
#   plt.tight_layout()
# C:\Users\shinw\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) Malgun Gothic.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### **Evaluation of the 70/30 Asset Allocation Portfolio Strategy**
# Asset allocation proves to be an effective way to reduce volatility without sacrificing returns. It pairs especially well with a regime-dependent strategy that switches between reversal and momentum.

# %% [markdown]
# ### **Step 6. CAPM Diagnostic of Portfolio Performance**

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\shinw\appdata\local\programs\python\python310\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\shinw\appdata\local\programs\python\python310\lib\site-packages (from openpyxl) (2.0.0)
# [notice] A new release of pip is available: 23.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
file_path = "cd91.csv"
df = pd.read_csv(file_path, encoding='utf-8')

rate_row = df.iloc[0, 5:]
rate_row.index = pd.to_datetime(rate_row.index, format="%Y/%m/%d")
rate_row = rate_row.astype(float)

# 리샘플링
daily_rate = rate_row.sort_index()
daily_rate.index.name = 'date'
monthly_rf = daily_rate.resample('M').last() / 100

# 월간 무위험 수익률
rf_monthly_return = monthly_rf / 12
rf_monthly_return.name = 'rf'
rf_monthly_return = rf_monthly_return.to_frame()

print(rf_monthly_return.head())
# Out:
#                   rf
# date
# 2015-01-31  0.001767
# 2015-02-28  0.001750
# 2015-03-31  0.001542
# 2015-04-30  0.001500
# 2015-05-31  0.001500
# C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\376493639.py:15: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_rf = daily_rate.resample('M').last() / 100  # 연금리를 소수로 변환 (ex. 2.13 → 0.0213)

# %%
import statsmodels.api as sm

# 월별 수익률
strategy_return = result['Strategy'].pct_change().dropna()
benchmark_return = result['KOSPI200'].pct_change().dropna()

# 무위험 수익률
rf = rf_monthly_return['rf']
rf = rf.loc[strategy_return.index]

# 초과 수익률
excess_strategy = strategy_return - rf
excess_benchmark = benchmark_return - rf

df_reg = pd.DataFrame({
    'y': excess_strategy,
    'x': excess_benchmark
}).dropna()

# 독립변수에 상수항 추가
X = sm.add_constant(df_reg['x'])
y = df_reg['y']

model = sm.OLS(y, X).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.014
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     1.607
# Date:                Mon, 01 Sep 2025   Prob (F-statistic):              0.207
# Time:                        18:25:40   Log-Likelihood:                 147.39
# No. Observations:                 118   AIC:                            -290.8
# Df Residuals:                     116   BIC:                            -285.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0028      0.006      0.435      0.664      -0.010       0.016
# x             -0.1664      0.131     -1.268      0.207      -0.426       0.094
# ==============================================================================
# Omnibus:                        6.939   Durbin-Watson:                   2.251
# Prob(Omnibus):                  0.031   Jarque-Bera (JB):               11.315
# Skew:                           0.159   Prob(JB):                      0.00349
# Kurtosis:                       4.483   Cond. No.                         20.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# C:\Users\shinw\AppData\Local\Temp\ipykernel_3312\1435573420.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   strategy_return = result['Strategy'].pct_change().dropna()

# %% [markdown]
# ### **Evaluation of the CAPM Regression**
# The strategy exhibits a market-neutral characteristic. It aims to generate returns regardless of overall market direction. However, both the alpha and beta are not statistically significant.
